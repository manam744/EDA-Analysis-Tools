# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from eda_tools import analyze_numeric_column, analyze_categorical_column

# تنظیمات گرافیکی
sns.set(style='whitegrid')
plt.rcParams['figure.figsize'] = (8, 5)

# -----------------------------
# 🧪 Example: Using EDA Tools
# -----------------------------

# Load Titanic dataset
df = sns.load_dataset('titanic')
df.head()

# -----------------------------
# 🎯 Analyze Numeric Column: 'fare'
# -----------------------------

analyze_numeric_column(df, 'fare', target='survived')

# -----------------------------
# 🎯 Analyze Categorical Column: 'embarked'
# -----------------------------

analyze_categorical_column(df, 'embarked', target='survived')

# -----------------------------
# ✅ Summary
# -----------------------------

print("\n✅ This notebook demonstrated how to use EDA tools to analyze numeric and categorical columns quickly.")
print("You can now extend it for other columns and datasets.")
